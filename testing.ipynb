# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import os
import cv2
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.python.keras.engine.sequential import Sequential
from tensorflow.python.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D, Activation
from keras.applications.vgg19 import VGG19
from keras.applications.vgg19 import preprocess_input
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import normalize
from tensorflow.keras import layers
from tensorflow.keras.utils import to_categorical

# %%
new_model = tf.keras.models.load_model('saved-models')

# %%
image = cv2.imread('dataset\\converted\\1.jpg')
grayscale = image[:, :, 0]
img = cv2.cvtColor(grayscale, cv2.COLOR_GRAY2RGB)
plt.imshow(image)
plt.show()

# %%
resized = tf.image.resize(img, (512,512))
plt.imshow(resized.numpy().astype(int))
plt.show()

# %%
predic = new_model.predict(np.expand_dims(resized/255,0))
# Out:
# 1/1 [==============================] - 0s 63ms/step

# %%
predic
# Out:
# array([[ 33.825203,  18.735344, -73.55301 ]], dtype=float32)

# %%
from mat73 import loadmat
path = 'dataset\\images\\1.mat'
data=loadmat(path)
img=data['cjdata']
labl = img['label']

# %%
"""
Correct Prediction
"""

labl
# Out:
# array(1.)
